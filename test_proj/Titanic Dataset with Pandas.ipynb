# %%
import pandas as pd

dataframe = pd.read_csv("titanic_dataset.csv")
dataframe.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataframe.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Select first row
dataframe.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
# Select three rows
dataframe.iloc[1:4]
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1  \
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
# Set index
dataframe_index = dataframe.set_index(dataframe['Name'])
# Show row
dataframe_index.loc['Heikkinen, Miss. Laina']
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
# Show top two rows where column 'sex' is 'female'
dataframe[dataframe['Sex'] == 'female'].head(2)
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1  \
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Filter rows
dataframe[(dataframe['Sex'] == 'female') & (dataframe['Age'] >= 40)]
# Out:
#      PassengerId  Survived  Pclass
# 11            12         1       1  \
# 15            16         1       2
# 40            41         0       3
# 52            53         1       1
# 132          133         0       3
# 161          162         1       2
# 167          168         0       3
# 177          178         0       1
# 194          195         1       1
# 195          196         1       1
# 254          255         0       3
# 259          260         1       2
# 268          269         1       1
# 272          273         1       2
# 275          276         1       1
# 276          277         0       3
# 299          300         1       1
# 319          320         1       1
# 337          338         1       1
# 346          347         1       2
# 362          363         0       3
# 366          367         1       1
# 380          381         1       1
# 432          433         1       2
# 440          441         1       2
# ...

# %%
# Calculate statistics
print('Maximum:', dataframe['Age'].max())
print('Minimum:', dataframe['Age'].min())
print('Mean:', dataframe['Age'].mean())
print('Sum:', dataframe['Age'].sum())
print('Count:', dataframe['Age'].count())
# Out:
# Maximum: 80.0
# Minimum: 0.42
# Mean: 29.69911764705882
# Sum: 21205.17
# Count: 714

# %%
# Select unique values
dataframe['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# Show counts
dataframe['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
#handling missing values
dataframe[dataframe['Age'].isnull()].head(2)
# Out:
#     PassengerId  Survived  Pclass                          Name   Sex  Age
# 5             6         0       3              Moran, Mr. James  male  NaN  \
# 17           18         1       2  Williams, Mr. Charles Eugene  male  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S

# %%
# Attempt to replace values with NaN
dataframe[dataframe['Sex'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
dataframe[dataframe['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 5              6         0       3                          Moran, Mr. James  \
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# grouping rows 

dataframe.groupby('Survived')['Name'].count()

# Group rows by the values of the column 'Sex', calculate mean
# of each group
# Out:
# Survived
# 0    549
# 1    342
# Name: Name, dtype: int64

# %%
# Group rows, calculate mean
dataframe.groupby(['Sex','Survived'])['Age'].mean()
# Out:
# Sex     Survived
# female  0           25.046875
#         1           28.847716
# male    0           31.618056
#         1           27.276022
# Name: Age, dtype: float64

# %%
# apply a function

# Create function
def uppercase(x):
    return x.upper()
# Apply function, show two rows
dataframe['Name'].applymap(lambda x :upper(x))[0:2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25300\1617744347.py in ?()
#       3 # Create function
#       4 def uppercase(x):
#       5     return x.upper()
#       6 # Apply function, show two rows
# ----> 7 dataframe['Name'].applymap(lambda x :upper(x))[0:2]
#
# C:\Work files\course content\test_proj\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'applymap'

# %%
# Group rows, apply function to groups
dataframe.groupby('Sex').apply(lambda x: x.count())
# Out:
#         PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket
# Sex
# female          314       314     314   314  314  261    314    314     314  \
# male            577       577     577   577  577  453    577    577     577
#
#         Fare  Cabin  Embarked
# Sex
# female   314     97       312
# male     577    107       577
